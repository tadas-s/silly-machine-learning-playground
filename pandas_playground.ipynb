# %% [markdown]
# # Selecting best book title from multiple candidates

# %%
import pandas as pd
import sklearn

# %% [markdown]
# ## Sample data

# %%
titles = pd.read_csv('./sample_multivendor_responses.csv').drop_duplicates()
titles.head()
# Out:
#          vendor           isbn  class  \
# 0       nielsen  9780194420983      2
# 1      worldcat  9780194420983      0
# 2  open-library  9780194420983      1
# 3        outpan  9780194420983      1
# 4       nielsen  9781589016811      2
#
#                                                title
# 0                 Practical English Usage: Paperback
# 1  Practical English usage : [easier, faster refe...
# 2                            Practical English Usage
# 3                            Practical English Usage
# 4       Just War: Authority, Tradition, and Practice

# %% [markdown]
# ## Manually classified data

# %%
training_data = titles[titles['class'].isin([0, 1, 2])]
training_data = training_data[['class', 'title']].drop_duplicates()
training_data.head()
# Out:
#    class                                              title
# 0      2                 Practical English Usage: Paperback
# 1      0  Practical English usage : [easier, faster refe...
# 2      1                            Practical English Usage
# 4      2       Just War: Authority, Tradition, and Practice
# 5      0        Just war authority, tradition, and practice

# %% [markdown]
# ## Unclassified data for testing

# %%
test_data = titles[titles['class'].isnull()][['isbn', 'title']].drop_duplicates()
test_data.head()
# Out:
#               isbn                                              title
# 310  9780273750758             Research Methods for Business Students
# 311  9780273750758             Research methods for business students
# 314  9781447143994                            Quad Rotorcraft Control
# 315  9781447143994  Quad rotorcraft control vision-based hovering ...
# 316  9780754631323  Pop Music: Technology and Creativity - Trevor ...

# %% [markdown]
# ## Feature extraction

# %%
import numpy as np
from collections import Counter
from string import punctuation, whitespace
import re
from functools import reduce

def feature_extract(title):
    features = []

    # Title length
    features.append(len(title))

    # Does it start with uppercase?
    features.append(int(title[0:1].isupper()))

    # How many punctuation characters?
    features.append(
        sum([v for k, v in Counter(title).items() if k in punctuation])
    )

    # How many less common punctuation characters?
    features.append(
        sum([v for k, v in Counter(title).items() if (k in punctuation) and (k not in '.,:\'')])
    )

    # Does it end with punctuation?
    features.append(
        int(len(title) and title[-1] in punctuation)
    )

    # How many whitespace characters?
    features.append(
        sum([v for k, v in Counter(title).items() if k in whitespace])
    )

    # How many whitespace separated words?
    features.append(len(title.split()))

    # What's an average length of uppercase words?
    upper_lengths = list(map(len, filter(lambda t: t[:1].isalpha() and t[:1].isupper(), title.split())))
    if len(upper_lengths):
        features.append(np.average(upper_lengths))
    else:
        features.append(0.0)

    # What's an average length of lowercase words?
    lower_lengths = list(map(len, filter(lambda t: t[:1].isalpha() and t[:1].islower(), title.split())))
    if len(lower_lengths):
        features.append(np.average(lower_lengths))
    else:
        features.append(0.0)

    # Does it split into title / subtitle?
    title_subtitle = list(filter(lambda e: e, title.split(': ')))

    features.append(
        len(title_subtitle)
    )

    # Assuming it splits into title/subtitle, is subtitle starts with uppercase?
    features.append(
        len(title_subtitle) > 1 and title_subtitle[1][0:1].isupper()
    )

    # Is title/subtitel split by " : "?
    features.append(
        int(" : " in title)
    )

    # Does it have any kind of text in parenthesis?
    features.append(
        len(re.findall("\[[^\]]*\]|\([^)]*\)|<[^>]*>|\{[^\}]*\}", title))
    )

    # Uppercase letter 'share'
    uppercase = reduce(lambda l, e: l + 1, filter(lambda l: l.isalpha() and l.isupper(), title), 0)
    if uppercase > 0:
        features.append(float(len(title)) / float(uppercase))
    else:
        features.append(0.0)

    # Lowercase letter 'share'
    lowercase = reduce(lambda l, e: l+1, filter(lambda l: l.isalpha() and l.islower(), title), 0)
    if lowercase > 0:
        features.append(float(len(title)) / float(lowercase))
    else:
        features.append(0.0)

    return features

# %% [markdown]
# ## Training

# %%
from sklearn.ensemble import RandomForestClassifier

clf = sklearn.ensemble.RandomForestClassifier(min_samples_split=4)

# %%
classes = [int(c) for (c, title) in training_data.as_matrix()]
features = [feature_extract(title) for (c, title) in training_data.as_matrix()]
clf.fit(features, classes)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=4, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0)

# %% [markdown]
# ## Example predictions

# %%
clf.predict_proba(feature_extract("Something Something Title"))
# Out:
# array([[ 0.,  1.,  0.]])

# %%
clf.predict_proba(feature_extract("Something: A Guide to Nothing"))
# Out:
# array([[ 0.03333333,  0.08333333,  0.88333333]])

# %%
clf.predict_proba(feature_extract("probably not good at all"))
# Out:
# array([[ 0.6,  0.4,  0. ]])

# %%
clf.predict_proba(feature_extract("Too Much Information, 2005, Publisher, New York"))
# Out:
# array([[ 0.56666667,  0.36666667,  0.06666667]])

# %%
clf.predict_proba(feature_extract(""))
# Out:
# array([[ 0.,  1.,  0.]])

# %% [markdown]
# ## Picking best from multiple candidates

# %%
def pick_one(titles):
    probs = [(title, clf.predict_proba(feature_extract(title))[0]) for title in titles]
    #probs = sorted(probs, key=lambda p: (-max(p[1][1], p[1][2]), p[1][0]))
    probs = sorted(
        probs,
        key=lambda p: (-max(p[1][1], p[1][2]), -min(p[1][1], p[1][2]), p[1][0])
    )
    return probs[0][0]

# %%
pick_one(["Something Something Title", "Something: A Guide to Nothing", "probably not good at all"])
# Out:
# 'Something Something Title'

# %% [markdown]
# ## Running on our test set

# %% [markdown]
# Group by ISBN and select ones that have a choice of at least 2 options

# %%
from itertools import groupby

grouped = groupby(
    [(r[1], r[2]) for r in test_data.to_records()],
    lambda v: v[0]
)

grouped = dict([(k,[t[1] for t in list(v)]) for (k,v) in grouped])
grouped = dict([(k,v) for (k,v) in grouped.items() if len(v) > 1])

# %%
for (isbn, titles) in grouped.items():
    print("\n\nCandidates:")
    print("\n".join(titles))
    print("Winner:")
    print(pick_one(titles))
# Out:
# Candidates:
# Cases and Materials on Constitutional and Administrative Law
# Cases and materials on constitutional and administrative law
# Winner:
# Cases and Materials on Constitutional and Administrative Law
#
#
# Candidates:
# Assessment for learning and teaching in primary schools
# Assessment for Learning and Teaching in Primary Schools
# Winner:
# Assessment for Learning and Teaching in Primary Schools
#
#
# Candidates:
# Echoes of History, Shadowed Identities: Rewriting Alterity in J. M. Coetzee's Foe and Marina Warner's Indigo
# Echoes of History, Shadowed Identities: Rewriting Alterity in J. M. Coetzee's Foe and Maria Warner's Indigo
# Echoes of history, shadowed identities
# Winner:
# Echoes of History, Shadowed Identities: Rewriting Alterity in J. M. Coetzee's Foe and Marina Warner's Indigo
#
#
# Candidates:
# Housework and Housewives in American Advertising: Married to the Mop
# Housework and Housewives in Modern American Advertising
# Housework and housewives in American advertising
# Winner:
# Housework and Housewives in Modern American Advertising
#
#
# Candidates:
# National Differences, Global Similarities: World Culture and the Future of Schooling
# National Differences, Global Similarities
# Winner:
# National Differences, Global Similarities: World Culture and the Future of Schooling
#
#
# Candidates:
# Immigration and German Identity in the Federal Republic of Germany from 1945 to 2006
# Immigration and German identity in the Federal Republic of Germany from 1945 to 2006
# Winner:
# Immigration and German Identity in the Federal Republic of Germany from 1945 to 2006
#
#
# Candidates:
# Social Work
# Social Work: An Introduction to Contemporary Practice
# Winner:
# Social Work
#
#
# Candidates:
# Social Structure
# Social structure
# Winner:
# Social Structure
#
#
# Candidates:
# Understanding Work - Based Learning
# Understanding work-based learning
# Understanding Work-Based Learning
# Winner:
# Understanding Work-Based Learning
#
#
# Candidates:
# Essays on Early Eastern Eucharistic Prayers
# Essays on early eastern eucharistic prayers : [based on a series of seminars for doctoral students in liturgical studies at the University of Notre Dame]
# Winner:
# Essays on Early Eastern Eucharistic Prayers
#
#
# Candidates:
# The American Design Adventure
# The American design adventure : 1940-1975
# The American design adventure, 1940-1975
# Winner:
# The American Design Adventure
#
#
# Candidates:
# The Neutronium Alchemist
# The neutronium alchemist
# The Neutronium Alchemist (Night's Dawn Trilogy)
# Neutronium Alchemist
# Winner:
# The Neutronium Alchemist
#
#
# Candidates:
# Pockets of Crime: Broken Windows, Collective Efficacy, and the Criminal Point of View
# Pockets of crime broken windows, collective efficacy, and the criminal point of view
# Winner:
# Pockets of Crime: Broken Windows, Collective Efficacy, and the Criminal Point of View
#
#
# Candidates:
# Web Social Science: Concepts, Data and Tools for Social Scientists in the Digital Age
# Web social science : concepts, data and tools for social scientists in the digital age
# Winner:
# Web Social Science: Concepts, Data and Tools for Social Scientists in the Digital Age
#
#
# Candidates:
# CRC Handbook of Chemistry and Physics: A Ready-Reference Book of Chemical and Physical Data
# CRC handbook of chemistry and physics : a ready-reference book of chemical and physical data.
# CRC Handbook of Chemistry and Physics, 2013-2014
# Winner:
# CRC Handbook of Chemistry and Physics: A Ready-Reference Book of Chemical and Physical Data
#
#
# Candidates:
# \Accompaninge the Players\": Essays Celebrating Thomas Middleton
# \Accompaninge the players\" : essays celebrating Thomas Middleton
# Accompaninge the Players: Essays Celebrating Thomas Middleton, 1581-1980
# Winner:
# Accompaninge the Players: Essays Celebrating Thomas Middleton, 1581-1980
#
#
# Candidates:
# Fundamentals of Nursing: The Art and Science of Nursing Care
# Fundamentals of nursing : the art and science of nursing care
# Fundamentals of nursing
# Winner:
# Fundamentals of Nursing: The Art and Science of Nursing Care
#
#
# Candidates:
# The Media in Contemporary France
# The media in contemporary France
# Winner:
# The Media in Contemporary France
#
#
# Candidates:
# The African diaspora in the Indian Ocean
# The African Diaspora in the Indian Ocean
# Winner:
# The African Diaspora in the Indian Ocean
#
#
# Candidates:
# Lifespan Development
# Lifespan development
# Lifespan Development (3rd Edition)
# Winner:
# Lifespan Development
#
#
# Candidates:
# Understanding Children's Development
# Understanding children's development
# Understanding Children?s Development
# Winner:
# Understanding Children's Development
#
#
# Candidates:
# Application of Nursing Process and Nursing Diagnosis
# Application of nursing process and nursing diagnosis : an interactive text for diagnostic reasoning
# Application of nursing process and nursing diagnosis
# Winner:
# Application of Nursing Process and Nursing Diagnosis
#
#
# Candidates:
# Room : a novel
# Room: A Novel
# Room
# Winner:
# Room
#
#
# Candidates:
# An Introduction to Applying Social Work Theories and Methods
# An introduction to applying social work theories and methods
# Winner:
# An Introduction to Applying Social Work Theories and Methods
#
#
# Candidates:
# Peacekeeping in Sierra Leone: The Story of UNAMSIL
# Peacekeeping in Sierra Leone
# Winner:
# Peacekeeping in Sierra Leone
#
#
# Candidates:
# Global Politics and the Responsibility to Protect: From Words to Deeds
# Global politics and the responsibility to protect : from words to deeds
# Global politics and the responsibilty to protect
# Winner:
# Global Politics and the Responsibility to Protect: From Words to Deeds
#
#
# Candidates:
# AQA Sociology A2: Student's Book
# AQA A2 sociology.
# Winner:
# AQA Sociology A2: Student's Book
#
#
# Candidates:
# Standards for Instructional Supervision: Enhancing Teaching and Learning
# Standards for instructional supervision : enhancing teaching and learning
# Standards for Instructional Supervision: Enhancing Teaching and Learning: Enhancing Teaching and Learning
# Winner:
# Standards for Instructional Supervision: Enhancing Teaching and Learning: Enhancing Teaching and Learning
#
#
# Candidates:
# Effective Communication Skills for Health Professionals
# Effective communication skills for health professionals.
# Effective Communication Skills for Health Professionals (Therapy in practice)
# Winner:
# Effective Communication Skills for Health Professionals
#
#
# Candidates:
# The Russian Folktale by Vladimir Yakolevich Propp
# The Russian folktale by Vladimir Yakovlevich Propp
# The Russian folktale by Vladimir Yakolevich Propp
# Winner:
# The Russian Folktale by Vladimir Yakolevich Propp
#
#
# Candidates:
# Organisational behaviour
# Organisational Behavior
# Winner:
# Organisational Behavior
#
#
# Candidates:
# An Integrated Approach to Communication Theory and Research
# An integrated approach to communication theory and research
# Integrated Approach To Communication Theory and Research
# Winner:
# Integrated Approach To Communication Theory and Research
#
#
# Candidates:
# AS Level Sociology: The Complete Course for the AQA Specification
# As Level Sociology The Complete Course for the Aqa Specification.
# AS Level Sociology: The Complete Course for the AQA Specification (The Complete Course for t...
# Winner:
# AS Level Sociology: The Complete Course for the AQA Specification
#
#
# Candidates:
# Cartographies of Knowledge: Exploring Qualitative Epistemologies
# Cartographies of knowledge : exploring qualitative epistemologies
# Winner:
# Cartographies of Knowledge: Exploring Qualitative Epistemologies
#
#
# Candidates:
# Social Research Methods
# Social research methods
# Winner:
# Social Research Methods
#
#
# Candidates:
# The Medieval Town in England 1200-1540
# English Medieval Town A Reader in English Urban History, 1200-1540
# Winner:
# The Medieval Town in England 1200-1540
#
#
# Candidates:
# The Assessment Handbook: The Complete Guide to the Successful Use of Assessment in Your School
# The assessment handbook
# Winner:
# The Assessment Handbook: The Complete Guide to the Successful Use of Assessment in Your School
#
#
# Candidates:
# Mediaeval Reformation
# The medieval reformation
# Mediaeval Reformation (Foundations of Mediaeval History)
# The Medieval Reformation (Foundations of Medieval History)
# Winner:
# Mediaeval Reformation
#
#
# Candidates:
# Vladimir Putin and the Evolution of Russian Foreign Policy
# Vladimir Putin and the evolution of Russian foreign policy
# Winner:
# Vladimir Putin and the Evolution of Russian Foreign Policy
#
#
# Candidates:
# From Old English to Standard English
# From Old English to Standard English : a course book in language variation across time
# From Old English to Standard English: A Course Book in Language Variation Across Time
# Winner:
# From Old English to Standard English
#
#
# Candidates:
# Write to TV: Out of Your Head and Onto the Screen
# Write to TV : out of your head and onto the screen
# Write to TV
# Write to TV: Out of Your Head and onto the Screen
# Winner:
# Write to TV
#
#
# Candidates:
# A Dictionary of Media and Communication
# A dictionary of media and communication
# Winner:
# A Dictionary of Media and Communication
#
#
# Candidates:
# An Introduction to Criminological Theory
# An introduction to criminological theory
# Winner:
# An Introduction to Criminological Theory
#
#
# Candidates:
# Recreational Terror: Women and the Pleasures of Horror Film Viewing
# Recreational terror
# Recreational terror women and the pleasures of horror film viewing
# Winner:
# Recreational Terror: Women and the Pleasures of Horror Film Viewing
#
#
# Candidates:
# The End of History and the Last Man
# The end of history and the last man
# Winner:
# The End of History and the Last Man
#
#
# Candidates:
# Nutrition and Diagnosis Related Care: Text and PDA CD-ROM Package
# Nutrition and Diagnosis-Related Care
# Winner:
# Nutrition and Diagnosis Related Care: Text and PDA CD-ROM Package
#
#
# Candidates:
# The Essential Groupworker: Teaching and Learning Creative Groupwork
# The essential groupworker : teaching and learning creative groupwork
# Essential Groupworker
# The Essential Groupworker
# Winner:
# Essential Groupworker
#
#
# Candidates:
# Desert solitaire
# Desert Solitaire: A Season in the Wilderness
# Winner:
# Desert Solitaire: A Season in the Wilderness
#
#
# Candidates:
# Teaching Primary English
# Teaching primary English
# Winner:
# Teaching Primary English
#
#
# Candidates:
# Public Law: Text, Cases, and Materials
# Public law : text, cases, and materials
# Public Law
# Winner:
# Public Law
#
#
# Candidates:
# Advocacy and Learning Disability
# Advocacy and learning disability
# Winner:
# Advocacy and Learning Disability
#
#
# Candidates:
# Language: Structure, Processing, and Disorders
# Language structure, processing, and disorders
# Language
# Winner:
# Language
#
#
# Candidates:
# War Over Kosovo: Politics and Strategy in a Global Age
# War over Kosovo politics and strategy in a global age
# War over Kosovo
# Winner:
# War Over Kosovo: Politics and Strategy in a Global Age
#
#
# Candidates:
# Theories of Childhood: An Introduction to Dewey, Montessori, Erickson, Piaget and Vygotsky
# Theories of childhood : an introduction to Dewey, Montessori, Erickson, Piaget and Vygotsky
# Theories of Childhood: An Introduction to Dewey, Montessori, Erikson, Piaget, and Vygotsky
# Winner:
# Theories of Childhood: An Introduction to Dewey, Montessori, Erikson, Piaget, and Vygotsky
#
#
# Candidates:
# Essentials of Pharmacology for Nurses
# Essentials of Pharmacology for Nurses.
# Winner:
# Essentials of Pharmacology for Nurses
#
#
# Candidates:
# Social Work Skills: A Practice Handbook
# Social Work Skills
# Winner:
# Social Work Skills
#
#
# Candidates:
# People Management: Challenges and Opportunities
# People Management
# Winner:
# People Management
#
#
# Candidates:
# Research methods for business students
# Research Methods for Business Students (5th Edition)
# Winner:
# Research methods for business students
#
#
# Candidates:
# Services marketing : text and cases
# Services Marketing: Text and Cases
# Services Marketing
# Winner:
# Services Marketing
#
#
# Candidates:
# Teaching for Musical Understanding
# Teaching for musical understanding
# Winner:
# Teaching for Musical Understanding
#
#
# Candidates:
# Collins English dictionary.
# Collins Express English Dictionary
# Collins English dictionary
# Winner:
# Collins Express English Dictionary
#
#
# Candidates:
# The Self in Social Psychology
# The self in social psychology
# The Self in social psychology
# Winner:
# The Self in Social Psychology
#
#
# Candidates:
# Attachment in Adulthood: Structure, Dynamics and Change
# Attachment in Adulthood: Structure, Dynamics, and Change
# Attachment in Adulthood
# Winner:
# Attachment in Adulthood: Structure, Dynamics, and Change
#
#
# Candidates:
# Subversive Sounds: Race and the Birth of Jazz in New Orleans
# Subversive sounds race and the birth of jazz in New Orleans
# Winner:
# Subversive Sounds: Race and the Birth of Jazz in New Orleans
#
#
# Candidates:
# Quad Rotorcraft Control
# Quad rotorcraft control vision-based hovering and navigation
# Winner:
# Quad Rotorcraft Control
#
#
# Candidates:
# Child Development for Early Childhood Studies
# Child development for early childhood studies
# Winner:
# Child Development for Early Childhood Studies
#
#
# Candidates:
# Education and the Family: Passing Success Across the Generations
# Education and the family : passing success across the generations
# Education and the Family
# Winner:
# Education and the Family
#
#
# Candidates:
# The Domestication of Women: Discrimination in Developing Societies
# The domestication of women : discrimination in developing societies
# The domestication of women: discrimination in developing societies
# The Domestication of Women
# Winner:
# The Domestication of Women
#
#
# Candidates:
# Child Care and Education
# Child care and education
# Winner:
# Child Care and Education
#
#
# Candidates:
# Spatial Planning and Governance: Understanding UK Planning
# Spatial Planning and Governance
# Spatial planning and governance
# Winner:
# Spatial Planning and Governance: Understanding UK Planning
#
#
# Candidates:
# Forgotten Children: Parent-Child Relations from 1500 to 1900
# Forgotten children : parent-child relations from 1500 to 1900
# Forgotten children
# Winner:
# Forgotten Children: Parent-Child Relations from 1500 to 1900
#
#
# Candidates:
# Photography: The Key Concepts
# Photography
# Winner:
# Photography
#
#
# Candidates:
# Formative Assessment in Action: Weaving the Elements Together
# Formative Assessment in Action
# Formative assessment in action : weaving the elements together
# Winner:
# Formative Assessment in Action
#
#
# Candidates:
# The Kinder, Gentler Military: How Political Correctness Affects Our Ability to Win Wars
# The kinder, gentler military
# The Kinder, Gentler Military
# Winner:
# The Kinder, Gentler Military: How Political Correctness Affects Our Ability to Win Wars
#
#
# Candidates:
# Sociology: A Global Introduction
# Sociology : a global introduction
# Sociology
# Winner:
# Sociology
#
#
# Candidates:
# A Philosophy of Intellectual Property
# A philosophy of intellectual property
# Philosophy of Intellectual Property
# Winner:
# A Philosophy of Intellectual Property
#
#
# Candidates:
# Research Methods for Business Students
# Research methods for business students
# Winner:
# Research Methods for Business Students
#
#
# Candidates:
# The Language of News Media
# The language of news media
# Winner:
# The Language of News Media
#
#
# Candidates:
# Project Management Planning and Control Techniques
# Project management : planning and control techniques
# Project Management
# Project Management (Knowledge Zone)
# Winner:
# Project Management Planning and Control Techniques
#
#
# Candidates:
# The Media Handbook: A Complete Guide to Advertising Media Selection, Planning, Research, and Buying
# The Media Handbook a Complete Guide to Advertising Media Selection, Planning, Research, and Buying.
# The media handbook
# Winner:
# The Media Handbook: A Complete Guide to Advertising Media Selection, Planning, Research, and Buying
#
#
# Candidates:
# Urban Outcasts: A Comparative Sociology of Advanced Marginality
# Urban outcasts : a comparative sociology of advanced marginality
# Urban outcasts
# Urban Outcasts
# Winner:
# Urban Outcasts
#
#
# Candidates:
# Texian Iliad: A Military History of the Texas Revolution, 1835-1836
# Texian iliad : a military history of the Texas Revolution, 1835-1836
# Texian Iliad A Military History of the Texas Revolution, 1835-1836
# Winner:
# Texian Iliad A Military History of the Texas Revolution, 1835-1836
#
#
# Candidates:
# Race and Slavery in the Middle East: An Historical Enquiry
# Race and slavery in the Middle East
# Winner:
# Race and Slavery in the Middle East: An Historical Enquiry
#
#
# Candidates:
# Postmodern Condition CB
# The postmodern condition
# Winner:
# Postmodern Condition CB
#
#
# Candidates:
# Project Management: A Managerial Approach
# Project management : a managerial approach.
# Winner:
# Project Management: A Managerial Approach
#
#
# Candidates:
# Criminal Justice in America
# Criminal justice in America
# Winner:
# Criminal Justice in America
#
#
# Candidates:
# Revolting Subjects: Social Abjection and Resistance in Neoliberal Britain
# Revolting subjects : social abjection and resistance in neoliberal Britain
# Revolting Subjects
# Winner:
# Revolting Subjects
#
#
# Candidates:
# Management of organizational behavior : leading human resources
# Management of organizational behavior
# Management of Organizational Behavior
# Winner:
# Management of Organizational Behavior
#
#
# Candidates:
# Beliefs and Ideologies
# Beliefs and ideologies
# Beliefs and ideology
# Winner:
# Beliefs and Ideologies
#
#
# Candidates:
# Sport and the British: A Modern History
# Sport and the British : a modern history
# Winner:
# Sport and the British: A Modern History
#
#
# Candidates:
# Principles of Marketing
# Principles of marketing
# Winner:
# Principles of Marketing
#
#
# Candidates:
# Making Formative Assessment Work: Effective Practice in the Primary Classroom
# Making formative assessment work : effective practice in the primary classroom
# Making Formative Assessment Work : Effective Practice in the Primary Classroom
# Winner:
# Making Formative Assessment Work: Effective Practice in the Primary Classroom
#
#
# Candidates:
# Sociocultural Theory and the Genesis of Second Language Development
# Sociocultural theory and the genesis of second language development
# Sociocultural Theory And the Genesis of Second Language
# Winner:
# Sociocultural Theory and the Genesis of Second Language Development
#
#
# Candidates:
# Skills for Success: Personal Development and Employability
# Skills for Success: The Personal Development Planning Handbook (Palgrave Study Guides)
# Winner:
# Skills for Success: Personal Development and Employability
#
#
# Candidates:
# The kite runner
# The Kite Runner (Alex Awards (Awards))
# Winner:
# The kite runner
#
#
# Candidates:
# ReelViews : the ultimate guide to the best 1,000 modern movies on DVD and video
# Reelviews: The Ultimate Guide to the Best 1,000 Modern Movies on Dvd and Video
# Winner:
# Reelviews: The Ultimate Guide to the Best 1,000 Modern Movies on Dvd and Video
#
#
# Candidates:
# The Letters of Elizabeth Gaskell
# The letters of Mrs. Gaskell
# The Letters of Mrs. Gaskell
# Winner:
# The Letters of Elizabeth Gaskell
#
#
# Candidates:
# Project Management
# Project management : achieving competitive advantage
# Winner:
# Project Management
#
#
# Candidates:
# Improve Your Communication Skills
# Improve your communication skills
# Improve Your Communication Skills (Creating Success)
# Winner:
# Improve Your Communication Skills
#
#
# Candidates:
# Effective School Leadership: Responding to Change
# Effective school leadership : responding to change
# Effective School Leadership : Responding to Change
# Winner:
# Effective School Leadership: Responding to Change
#
#
# Candidates:
# Basic Infection Control for the Health Care Profession
# Basic infection control for health care providers
# Basic Infection Control for the Health Care Professional
# Winner:
# Basic Infection Control for the Health Care Profession
#
#
# Candidates:
# Essentials of Pediatric Nursing
# Essentials of pediatric nursing
# Winner:
# Essentials of Pediatric Nursing
#
#
# Candidates:
# Education in Britain: 1944 to the Present
# Education in Britain : 1944 to present
# Winner:
# Education in Britain: 1944 to the Present
#
#
# Candidates:
# The German Ideology
# The German ideology
# German Ideology, Vol. 3
# Winner:
# The German Ideology
#
#
# Candidates:
# Developmental Biology
# Developmental biology
# Winner:
# Developmental Biology
#
#
# Candidates:
# Essential Midwifery Practice: Public Health
# Essential Midwifery Practice
# Essential midwifery practice
# Winner:
# Essential Midwifery Practice
#
#
# Candidates:
# Hannibal
# Hannibal (Hannibal Lecter Series #3)
# Winner:
# Hannibal
#
#
# Candidates:
# Effective Legal Research
# Effective legal research
# Winner:
# Effective Legal Research
#
#
# Candidates:
# Fundamentals of Anatomy and Physiology for Student Nurses
# Fundamentals of anatomy and physiology for student nurses
# Winner:
# Fundamentals of Anatomy and Physiology for Student Nurses
#
#
# Candidates:
# A Second Chance at Eden
# A second chance at Eden
# Winner:
# A Second Chance at Eden
#
#
# Candidates:
# The Roper-Logan-Tierney Model of Nursing: Based on Activities of Living
# The Roper Logan and Tierney Model Nursing: Based on Activities of Living
# The Roper-Logan-Tierney Model of Nursing
# Winner:
# The Roper Logan and Tierney Model Nursing: Based on Activities of Living
#
#
# Candidates:
# The Evidence-Based Practice Manual for Nurses
# The evidence-based practice manual for nurses
# Winner:
# The Evidence-Based Practice Manual for Nurses
#
#
# Candidates:
# Seminars in the Psychiatry of Learning Disability
# Seminars in the psychiatry of learning disabilities
# Winner:
# Seminars in the Psychiatry of Learning Disability
#
#
# Candidates:
# Complete Psychology
# Complete psychology.
# Complete psychology
# Winner:
# Complete Psychology
#
#
# Candidates:
# A Short History of the Liberal Party, 1900-97
# A short history of the Liberal Party, 1900-1997
# Winner:
# A Short History of the Liberal Party, 1900-97
#
#
# Candidates:
# Cooperative Chemistry Lab Manual
# Cooperative chemistry laboratory manual
# Winner:
# Cooperative Chemistry Lab Manual
#
#
# Candidates:
# Essentials of Construction Project Management
# Essentials of construction project management
# Winner:
# Essentials of Construction Project Management
#
#
# Candidates:
# The Odyssey
# Homer The Odyssey.
# The Odyssey (Fagles translation)
# The Odyssey (Penguin Classics)
# Winner:
# The Odyssey
#
#
# Candidates:
# The Ultimate Film Guides: \Psycho\""
# Psycho
# Winner:
# Psycho
#
#
# Candidates:
# International Business: Challenges in a Changing World
# International business : challenges in a changing world
# International business
# Winner:
# International Business: Challenges in a Changing World
#
#
# Candidates:
# Union in Truth-Spec: An Interpretive History of the Restoration Movement
# Union in truth
# Winner:
# Union in Truth-Spec: An Interpretive History of the Restoration Movement
#
#
# Candidates:
# Mastering Communication
# Mastering communication
# Winner:
# Mastering Communication
#
#
# Candidates:
# On Record #
# On record : rock, pop, and the written word
# On record
# Winner:
# On Record #
#
#
# Candidates:
# Practitioner Research for Teachers
# Practitioner research for teachers
# Winner:
# Practitioner Research for Teachers
#
#
# Candidates:
# Chronicles of the Cross: No Wonder They Call Him the Savior/Six Hours One Friday/And the Angels Were Silent
# Chronicles of the Cross Collection
# Winner:
# Chronicles of the Cross Collection
#
#
# Candidates:
# Reflective Practice: Writing and Professional Development
# Reflective Practice Writing and Professional Development.
# Winner:
# Reflective Practice: Writing and Professional Development
#
#
# Candidates:
# Feminisms: A Reader
# Feminisms
# Winner:
# Feminisms
#
#
# Candidates:
# In Europe's Name: Germany and the Divided Continent
# In Europe's Name
# Winner:
# In Europe's Name: Germany and the Divided Continent
#
#
# Candidates:
# Taking Minutes of Meetings
# Taking minutes of meetings
# Taking Minutes of Meetings (Creating Success)
# Winner:
# Taking Minutes of Meetings
#
#
# Candidates:
# Urban Fortunes: The Political Economy of Place
# Urban fortunes : the political economy of place
# Urban fortunes
# Winner:
# Urban Fortunes: The Political Economy of Place
#
#
# Candidates:
# Social Work with Adults: Policy, Law, Theory, Research and Practice
# Social work with adults
# Social Work with Adults
# Winner:
# Social Work with Adults
#
#
# Candidates:
# Companion Animals in Human Health
# Companion animals in human health
# Winner:
# Companion Animals in Human Health
#
#
# Candidates:
# Natural Resource Management for Sustainable Development in the Caribbean
# Natural resource management for sustainable development in the Caribbean
# Winner:
# Natural Resource Management for Sustainable Development in the Caribbean
#
#
# Candidates:
# Assessment for Learning: Putting it into Practice
# Assessment for learning : putting it into practice
# Assessment for learning
# Winner:
# Assessment for Learning: Putting it into Practice
#
#
# Candidates:
# Stuart and Sundeen's Mental Health Nursing: Principles and Practice: UK Version
# Stuart and Sundeen's mental health nursing : principles and practice
# Stuart and Sundeen's mental health nursing
# Stuart and Sundeen's Mental Health Nursing
# Winner:
# Stuart and Sundeen's Mental Health Nursing: Principles and Practice: UK Version
#
#
# Candidates:
# Reflective Teaching: Evidence-informed Professional Practice
# Reflective Teaching 3rd Edition: Evidence-informed Professional Practice
# Reflective teaching
# Winner:
# Reflective Teaching: Evidence-informed Professional Practice
#
#
# Candidates:
# Technopoly
# Technopoly : the surrender of culture to technology
# Technopoly: The Surrender of Culture to Technology
# Winner:
# Technopoly
#
#
# Candidates:
# The Architects of the Parthenon
# The architects of the Parthenon
# Architects of the Parthenon
# Winner:
# The Architects of the Parthenon
#
#
# Candidates:
# Child Observation for Learning and Research
# Child observation for learning and research
# Winner:
# Child Observation for Learning and Research
#
#
# Candidates:
# Qualitative Text Analysis: A Guide to Methods, Practice and Using Software
# Qualitative text analysis : a guide to methods, practice and using software
# Winner:
# Qualitative Text Analysis: A Guide to Methods, Practice and Using Software
#
#
# Candidates:
# The Evolutionary Void
# The evolutionary void
# Winner:
# The Evolutionary Void
#
#
# Candidates:
# Subsea Engineering Handbook
# Subsea engineering handbook
# Winner:
# Subsea Engineering Handbook
#
#
# Candidates:
# Leadership in Nonprofit Organizations: Lessons from the Third Sector
# Leadership in nonprofit organizations
# Winner:
# Leadership in Nonprofit Organizations: Lessons from the Third Sector
#
#
# Candidates:
# Key Methods in Geography
# Key methods in geography
# Winner:
# Key Methods in Geography
#
#
# Candidates:
# As You Like it
# As you like it
# As You Like It
# Winner:
# As You Like it
#
#
# Candidates:
# Assessment and Learning in the Primary School
# Assessment and learning in the primary school
# Winner:
# Assessment and Learning in the Primary School
#
#
# Candidates:
# Work Psychology
# Work psychology
# Winner:
# Work Psychology
#
#
# Candidates:
# Understanding Social Enterprise: Theory and Practice
# Understanding Social Enterprise
# Understanding social enterprise
# Winner:
# Understanding Social Enterprise: Theory and Practice
#
#
# Candidates:
# Postmodernist Culture: An Introduction to Theories of the Contemporary
# Postmodernist Culture 2e
# Postmodernist Culture
# Winner:
# Postmodernist Culture
#
#
# Candidates:
# Communication and Interpersonal Skills in Social Work
# Communication and interpersonal skills in social work
# Winner:
# Communication and Interpersonal Skills in Social Work
#
#
# Candidates:
# Beyond Friendship: The Future of Anglo-American Relations
# Beyond Friendship
# Winner:
# Beyond Friendship
#
#
# Candidates:
# Murder of a Mafia Daughter: The Life and Tragic Death of Susan Berman
# Murder of a Mafia daughter : the life and tragic death of Susan Berman
# Murder of a Mafia Daughter
# Winner:
# Murder of a Mafia Daughter
#
#
# Candidates:
# Sharing Our World 1: Living Together in Our Home and School: Pupil's Book
# People Management Challenges and Opportunities
# Winner:
# People Management Challenges and Opportunities
#
#
# Candidates:
# Understanding the American Promise: A History, Volume I: To 1877: A History of the United States
# Understanding the American Promise
# Winner:
# Understanding the American Promise
#
#
# Candidates:
# Moral Philosophy from Montaigne to Kant: An Anthology: v.1
# Moral philosophy from Montaigne to Kant : an anthology
# Moral philosophy from Montaigne to Kant
# Winner:
# Moral Philosophy from Montaigne to Kant: An Anthology: v.1
#
#
# Candidates:
# Employability Skills
# Employability skills
# Winner:
# Employability Skills
#
#
# Candidates:
# Marketing: An Introduction
# Marketing : an introduction
# Winner:
# Marketing: An Introduction
#
#
# Candidates:
# The Children Act in Practice
# The Children Act in practice
# The Children ACT in Practice
# Winner:
# The Children Act in Practice
#
#
# Candidates:
# Leadership: Limits and Possibilities
# Leadership : Limits and Possibilities.
# Leadership
# Winner:
# Leadership
#
#
# Candidates:
# A Modern History of Japan: From Tokugawa Times to the Present
# A modern history of Japan : from Tokugawa times to the present
# Winner:
# A Modern History of Japan: From Tokugawa Times to the Present
#
#
# Candidates:
# The Girl with a Baby
# The girl with a baby
# Girl with a Baby
# The Girl With a Baby
# Winner:
# The Girl with a Baby
#
#
# Candidates:
# Successful Women Think Differently: 9 Habits to Make You Happier, Healthier, and More Resilient
# Successful women think differently
# Successful Women Think Differently
# Winner:
# Successful Women Think Differently
#
#
# Candidates:
# The Managing Care Reader
# The managing care reader
# Managing Care Reader
# Winner:
# Managing Care Reader
#
#
# Candidates:
# Subsea Engineering Handbook
# Subsea structural engineering handbook
# Subsea Structural Engineering Handbook
# Winner:
# Subsea Engineering Handbook
#
#
# Candidates:
# The Moon Is a Harsh Mistress
# Moon Is Harsh Mistres
# Winner:
# The Moon Is a Harsh Mistress
#
#
# Candidates:
# The Horror Film
# The horror film
# Winner:
# The Horror Film
#
#
# Candidates:
# The Later Medieval City: 1300-1500
# A history of urban society in Europe.
# Later Medieval City: 1300-1500
# Winner:
# Later Medieval City: 1300-1500
#
#
# Candidates:
# Naked God
# The naked god.
# The Naked God Pt. 2: Faith
# The naked god
# Winner:
# Naked God
#
#
# Candidates:
# Judas Unchained
# Judas unchained
# Winner:
# Judas Unchained
#
#
# Candidates:
# Child Development
# Child development
# Winner:
# Child Development
#
#
# Candidates:
# Sociology A2 for AQA
# Collins A2 sociology
# Sociology A2 for AQA (Collins A Level Sociology)
# Winner:
# Sociology A2 for AQA
#
#
# Candidates:
# Organizational Behavior
# Organizational behavior
# Winner:
# Organizational Behavior
#
#
# Candidates:
# Actfl: Action for the '80'S: Vol 12
# Action for the '80s : a political, professional and public program for foreign language education.
# Action for the '80s A Political, Professional and Public Program for Foreign Language Education
# Action for the '80s
# Winner:
# Actfl: Action for the '80'S: Vol 12
#
#
# Candidates:
# Condemned to Repeat?: The Paradox of Humanitarian Action
# Condemned to Repeat: The Paradox of Humanitarian Action
# Condemned to Repeat?
# Winner:
# Condemned to Repeat: The Paradox of Humanitarian Action
#
#
# Candidates:
# Culture, Gender and Identity: The British Middle Classes, 1795-1939
# Gender, civic culture, and consumerism
# Gender, Civic Culture and Consumerism
# Winner:
# Gender, Civic Culture and Consumerism
#
#
# Candidates:
# A Psychological Warfare Casebook
# A psychological warfare casebook
# Winner:
# A Psychological Warfare Casebook
#
#
# Candidates:
# Effective Business Communication: Perspectives, principles and practices
# Effective organisational communication : perspectives, principles and practices
# Effective Organisational Communication: Perspectives, Principles, and Practices
# Winner:
# Effective Organisational Communication: Perspectives, Principles, and Practices
#
#
# Candidates:
# Social Work Theory: A Straightforward Guide for Practice Assessors and Placement Supervisors
# Social work theory : a straightforward guide for practice assessors and placement supervisors
# Winner:
# Social Work Theory: A Straightforward Guide for Practice Assessors and Placement Supervisors
#
#
# Candidates:
# Singapore, the Energy Economy: from the First Refinery to the End of Cheap Oil, 1960-2010
# Singapore, the energy economy : from the first refinery to the end of cheap oil, 1960-2010
# Singapore, the Energy Economy
# Singapore, the energy economy
# Winner:
# Singapore, the Energy Economy
#
#
# Candidates:
# Racisms : an introduction
# Racism: An Introduction
# Winner:
# Racism: An Introduction
#
#
# Candidates:
# International Encyclopedia of Marriage and the Family
# International encyclopedia of marriage and family
# International Encyclopedia of Marriage and Family
# Winner:
# International Encyclopedia of Marriage and Family
#
#
# Candidates:
# The Practice of Nursing Research: Conduct, Critique and Utilization
# The practice of nursing research : conduct, critique, and utilization
# The practice of nursing research
# Winner:
# The Practice of Nursing Research: Conduct, Critique and Utilization
#
#
# Candidates:
# A Kiss of Shadows
# A kiss of shadows.
# Winner:
# A Kiss of Shadows
#
#
# Candidates:
# Social Web Evolution: Integrating Semantic Applications and Web 2.0 Technologies
# Social web evolution : integrating semantic applications and Web 2.0 technologies
# Social web evolution
# Winner:
# Social Web Evolution: Integrating Semantic Applications and Web 2.0 Technologies
#
#
# Candidates:
# Population Limitation in Birds
# Population limitation in birds
# Winner:
# Population Limitation in Birds
#
#
# Candidates:
# The Glorious Cause: The American Revolution, 1763-1789
# The glorious cause : the American Revolution 1763-1789
# The Glorious Cause
# Glorious Cause: The American Revolution, 1763-1789, Vol. 3
# Winner:
# The Glorious Cause
#
#
# Candidates:
# Wild Animus
# Wild animus
# Wild Animus : A Novel
# Winner:
# Wild Animus
#
#
# Candidates:
# Amer Govmt Politic Today
# American government and politics today
# Winner:
# Amer Govmt Politic Today
#
#
# Candidates:
# Hearing the Voices of Children: Social Policy for a New Century
# Hearing the voices of children : social policy for a new century
# Hearing the Voices of Children
# Winner:
# Hearing the Voices of Children
#
#
# Candidates:
# Mental Capacity ACT 2005: Deprivation of Liberty Safeguards: Code of Practice to Supplement the Main Mental Capacity ACT 2005 Code of Practice: Laid Before Parliament in Draft June 2008, Pursuant to Sections 42 and 43 of the ACT
# Mental Capacity Act 2005 : deprivation of liberty safeguards : Code of Practice to supplement the main Mental Capacity Act 2005 Code of Practice : laid before Parliament in draft June 2008, pursuant to sections 42 and 43 of the Act
# Mental Capacity ACT 2005: Deprivation of Liberty Safeguards: Code of Practice to Supplement the Main Mental Capacity ACT 2005 Code of Practice:
# Mental Capacity Act 2005
# Winner:
# Mental Capacity Act 2005
#
#
# Candidates:
# Hannibal Rising
# Hannibal rising
# Winner:
# Hannibal Rising
#
#
# Candidates:
# Narcissus in Chains
# Narcissus in chains
# Winner:
# Narcissus in Chains
#
#
# Candidates:
# Active Learning Through Formative Assessment
# Active learning through formative assessment
# Winner:
# Active Learning Through Formative Assessment
#
#
# Candidates:
# Research Methods for Nursing and Healthcare
# Research methods for nursing and healthcare
# Research methods for nurses
# Winner:
# Research Methods for Nursing and Healthcare
#
#
# Candidates:
# You can find inspiration in everything* : *and if you can't, look again
# Paul Smith: You Can Find Inspiration in Everything*
# Winner:
# Paul Smith: You Can Find Inspiration in Everything*
#
#
# Candidates:
# Assessment: What's in it for Schools?
# Assessment : what's in it for schools?
# Assessment
# Winner:
# Assessment
#
#
# Candidates:
# Psychology of Pain
# Psychology of pain
# Winner:
# Psychology of Pain
#
#
# Candidates:
# Wind Energy Conversion Systems: Technology and Trends
# Wind energy conversion system
# Wind energy conversion systems
# Wind Energy Conversion Systems
# Winner:
# Wind Energy Conversion Systems: Technology and Trends
#
#
# Candidates:
# Introductory Sociology
# Introductory sociology
# Winner:
# Introductory Sociology
#
#
# Candidates:
# Input and Interaction in Language Acquisition
# Input and interaction in language acquisition
# Winner:
# Input and Interaction in Language Acquisition
#
#
# Candidates:
# The Mental Capacity Act 2005: A Guide for Practice
# The Mental Capacity Act 2005 : a guide for practice
# The Mental Capacity ACT 2005: A Guide for Practice: Second Edition
# The Mental Capacity Act 2005
# Winner:
# The Mental Capacity Act 2005
#
#
# Candidates:
# Aspects of Semantic Transposition of Words
# Aspects of semantic transposition of words
# Winner:
# Aspects of Semantic Transposition of Words
#
#
# Candidates:
# The twentieth century
# The Twentieth Century: A People's History
# Winner:
# The Twentieth Century: A People's History
#
#
# Candidates:
# Conceptual Foundations of Occupational Therapy Practice
# Conceptual foundations of occupational therapy practice
# Winner:
# Conceptual Foundations of Occupational Therapy Practice
#
#
# Candidates:
# Writing Your MBA Dissertation
# Writing your MBA dissertation
# Winner:
# Writing Your MBA Dissertation
#
#
# Candidates:
# Texian Iliad: A Military History of the Texas Revolution
# Texian Iliad A Military History of the Texas Revolution, 1835-1836
# Texian Iliad
# Winner:
# Texian Iliad
#
#
# Candidates:
# Strategic Brand Management
# Strategic brand management
# Winner:
# Strategic Brand Management
#
#
# Candidates:
# Perspectives on Play: Learning for Life
# Perspectives on play : learning for life
# Perspectives on play
# Winner:
# Perspectives on Play: Learning for Life
#
#
# Candidates:
# European Union Law
# European Union law
# Winner:
# European Union Law
#
#
# Candidates:
# Pop Music: Technology and Creativity - Trevor Horn and the Digital Revolution
# Pop music
# Winner:
# Pop Music: Technology and Creativity - Trevor Horn and the Digital Revolution
#
#
# Candidates:
# Research methods for business students
# Research Methods for Business Students
# Winner:
# Research Methods for Business Students
#
#
# Candidates:
# Sociology Themes and Perspectives
# Sociology : themes and perspectives
# Winner:
# Sociology Themes and Perspectives
#
#
# Candidates:
# Biomechanics of Sport and Exercise
# Biomechanics of sport and exercise
# Biomechanics of Sport and Exercise with Web Resource and Maxtraq 2D Software Access-3rd Edition
# Winner:
# Biomechanics of Sport and Exercise
#
#
# Candidates:
# Assignment in Eternity
# Assignment in eternity
# Winner:
# Assignment in Eternity
#
#
# Candidates:
# Blue Moon
# Blue moon
# Blue Moon (Anita Blake Vampire Hunter Series #8)
# Winner:
# Blue Moon
#
#
# Candidates:
# The African Diaspora in the Mediterranean Lands of Islam
# The African diaspora in the Mediterranean lands of Islam
# Winner:
# The African Diaspora in the Mediterranean Lands of Islam
#
#
# Candidates:
# Genre and Contemporary Hollywood
# Genre and contemporary Hollywood
# Winner:
# Genre and Contemporary Hollywood
#
#
# Candidates:
# Misspent Youth
# Misspent youth
# Winner:
# Misspent Youth
#
#
# Candidates:
# A World History of Architecture
# A world history of architecture
# Winner:
# A World History of Architecture
#
#
# Candidates:
# Understanding Health Inequalities
# Understanding health inequalities
# Winner:
# Understanding Health Inequalities
#
#
# Candidates:
# In Your Hands: NLP in ELT
# In Your Hands: Nlp in Elt
# In Your Hands
# Winner:
# In Your Hands
#
#
# Candidates:
# Assessment and learning
# Assessment for Learning : Theory, Policy and Practice
# Assessment and Learning
# Winner:
# Assessment and Learning
#
#
# Candidates:
# The Male Body: A New Look at Men in Public and Private
# The male body : a new look at men in public and in private
# The male body
# The Male Body
# Winner:
# The Male Body
#
#
# Candidates:
# The Belbin Guide to Succeeding at Work
# The Belbin guide to succeeding at work.
# Winner:
# The Belbin Guide to Succeeding at Work
#
#
# Candidates:
# The Long Habit of Living
# The long habit of living
# Winner:
# The Long Habit of Living
#
#
# Candidates:
# Marketing: An Introductory Text
# Marketing : an introductory text
# Marketing
# Winner:
# Marketing
#
#
# Candidates:
# Thinking in Pictures: And Other Reports from My Life with Autism
# Thinking in pictures : and other reports from my life with autism
# Winner:
# Thinking in Pictures: And Other Reports from My Life with Autism
#
#
# Candidates:
# Handbook of Aqueous Solubility Data
# Handbook of aqueous solubility data
# Winner:
# Handbook of Aqueous Solubility Data
#
#
# Candidates:
# Shell Shock to PTSD: Military Psychiatry from 1900 to the Gulf War
# Shell shock to PTSD : military psychiatry from 1900 to the Gulf War
# Winner:
# Shell Shock to PTSD: Military Psychiatry from 1900 to the Gulf War
#
#
# Candidates:
# Promoting Equality: Challenging Discrimination and Oppression
# Promoting equality : challenging discrimination and oppression
# Promoting Equality : Challenging Discrimination and Oppression
# Winner:
# Promoting Equality: Challenging Discrimination and Oppression
#
#
# Candidates:
# Construction Technology 1: House Construction
# Construction technology: 1: house constru ction.
# Winner:
# Construction Technology 1: House Construction
#
#
# Candidates:
# On Being a Therapist
# On being a therapist
# Winner:
# On Being a Therapist
#
#
# Candidates:
# Andy Warhol: Headshots - Essays by Bob Colacello
# Andy Warhol, headshots, drawings and paintings
# Andy Warhol: Headshots
# Andy Warhol
# Winner:
# Andy Warhol
#
#
# Candidates:
# Governing the Commons: The Evolution of Institutions for Collective Action
# Governing the commons : the evolution of institutions for collective action
# Winner:
# Governing the Commons: The Evolution of Institutions for Collective Action
#
#
# Candidates:
# Adrienne Rich : the moment of change
# Adrienne Rich
# Winner:
# Adrienne Rich
#
#
# Candidates:
# Sh*t My Dad Says
# Sh*t my dad says
# Shit My Dad Says
# Winner:
# Shit My Dad Says
#
#
# Candidates:
# The State of the World's Refugees: Human Displacement in the New Millennium
# The state of the world's refugees 2006
# The state of the world's refugees, 2006
# Winner:
# The State of the World's Refugees: Human Displacement in the New Millennium
#
#
# Candidates:
# Consumerism: As a Way of Life
# Consumerism : as a way of life
# Winner:
# Consumerism: As a Way of Life
#
#
# Candidates:
# Ecrits Sur Le Theatre
# Écrits sur le théâtre
# Ecrits sur le theatre
# Brecht
# Winner:
# Brecht
#
#
# Candidates:
# The Autistic Brain: Thinking Across the Spectrum
# The autistic brain : thinking across the spectrum
# Winner:
# The Autistic Brain: Thinking Across the Spectrum
#
#
# Candidates:
# Grand Design: Hollywood as a Modern Business Enterprise, 1930-1939
# Grand Design
# Winner:
# Grand Design
#
#
# Candidates:
# Processes of Technological Innovation
# The processes of technological innovation
# The Processes of Technological Innovation
# Winner:
# The Processes of Technological Innovation
#
#
# Candidates:
# BTEC National in Public Services: Level 2: Student Book
# BTEC National in Public Services (Uniformed).
# BTEC National in Public Services: Student Book Level 2 (BTEC National Uniformed Public Services)
# Winner:
# BTEC National in Public Services: Level 2: Student Book
#
#
# Candidates:
# Strategic Marketing: Creating Competitive Advantage
# Strategic marketing : creating competitive advantage
# Strategic marketing
# Winner:
# Strategic Marketing: Creating Competitive Advantage
#
#
# Candidates:
# Andy Warhol Portraits
# Andy Warhol portraits
# Warhol Portraits
# Winner:
# Andy Warhol Portraits
#
#
# Candidates:
# Warriors and Worriers: The Survival of the Sexes
# Warriors and Worriers
# Winner:
# Warriors and Worriers
#
#
# Candidates:
# A Child's Journey Through Placement
# A child's journey through placement
# Winner:
# A Child's Journey Through Placement
#
#
# Candidates:
# Sweet Land of Liberty?: African-American Struggle for Civil Rights in the Twentieth Century
# Sweet land of liberty?
# Winner:
# Sweet Land of Liberty?: African-American Struggle for Civil Rights in the Twentieth Century
#
#
# Candidates:
# Orientalism: Western Conceptions of the Orient
# Orientalism
# Orientalism (Penguin Modern Classics)
# Winner:
# Orientalism
#
#
# Candidates:
# The Development of Islamic Ritual
# The development of Islamic ritual
# Winner:
# The Development of Islamic Ritual
#
#
# Candidates:
# Russia: Lost in Transition: The Yeltsin and Putin Legacies
# Russia - Lost in Transition
# Winner:
# Russia: Lost in Transition: The Yeltsin and Putin Legacies
#
#
# Candidates:
# The Well-Being of Children in the UK
# The well-being of children in the UK
# The Well-being of children in the UK
# Winner:
# The Well-Being of Children in the UK
#
#
# Candidates:
# Work-based Learning: A New Higher Education?
# Work-Based Learning A New Higher Education?
# Work-Based Learning
# Winner:
# Work-based Learning: A New Higher Education?
#
#
# Candidates:
# Essays in Positive Economics
# Essays in positive economics
# Essays in Positive Economics (Phoenix Books)
# Winner:
# Essays in Positive Economics
#
#
# Candidates:
# Communicating for Managerial Effectiveness: Problems, Strategies, Solutions
# Communicating for Managerial Effectiveness: Problems | Strategies | Solutions
# Winner:
# Communicating for Managerial Effectiveness: Problems, Strategies, Solutions
#
#
# Candidates:
# Classroom Instruction That Works: Research Based Strategies for Increasing Student Achievement
# Classroom Instruction That Works: Research-Based Strategies for Increasing Student Achievement
# Classroom Instruction That Works
# Winner:
# Classroom Instruction That Works
#
#
# Candidates:
# Child Development
# Child development
# Winner:
# Child Development
#
#
# Candidates:
# The shape of the liturgy
# The Shape of the Liturgy
# Winner:
# The Shape of the Liturgy
#
#
# Candidates:
# Enriching Feedback in the Primary Classroom: Oral and Written Feedback from Teachers and Children
# Enriching feedback in the primary classroom : oral and written feedback from teachers and children
# Enriching Feedback in the Primary Classroom
# Winner:
# Enriching Feedback in the Primary Classroom
#
#
# Candidates:
# Hadith: A Re-Evaluation
# Hadith
# Winner:
# Hadith
#
#
# Candidates:
# America, Russia and the Cold War 1945-2006
# America, Russia, and the Cold War, 1945-2005
# America, Russia, and the Cold War, 1945-2006
# Winner:
# America, Russia and the Cold War 1945-2006
#
#
# Candidates:
# The Bass Handbook of Leadership: Theory, Research, and Managerial Applications
# The Bass handbook of leadership : theory, research, and managerial applications
# The Bass handbook of leadership
# Winner:
# The Bass Handbook of Leadership: Theory, Research, and Managerial Applications
#
#
# Candidates:
# A Caress of Twilight
# A caress of twilight
# A Caress of Twilight (Meredith Gentry Series #2)
# Winner:
# A Caress of Twilight
#
#
# Candidates:
# Designing with Light and Shadow
# Designing with light and shadow
# Winner:
# Designing with Light and Shadow
#
#
# Candidates:
# The Dreaming Void
# The dreaming void
# Winner:
# The Dreaming Void
#
#
# Candidates:
# Francois Truffaut: Interviews
# François Truffaut : interviews
# Francois Truffaut
# Winner:
# Francois Truffaut
#
#
# Candidates:
# Cultural Criminology: An Invitation
# Cultural criminology : an invitation
# Cultural Criminology
# Winner:
# Cultural Criminology
#
#
# Candidates:
# Doing your early years research project : a step-by-step guide
# Doing Your Early Years Research Project: A Step-by-Step Guide
# Doing Your Early Years Research Project
# Winner:
# Doing Your Early Years Research Project
#
#
# Candidates:
# City Limits: Crime Consumer Culture and the Urban Experience
# City limits : crime, consumer culture and the urban experience
# City Limits: Crime, Consumer Culture and the Urban Experience
# Winner:
# City Limits: Crime Consumer Culture and the Urban Experience
#
#
# Candidates:
# The Psychology of Women at Work: Challenges and Solutions for Our Female Workforce
# The psychology of women at work : challenges and solutions for our female workforce
# Psychology of Women at Work [Three Volumes]: Challenges and Solutions for Our Female Workforce
# The psychology of women at work
# Winner:
# The Psychology of Women at Work: Challenges and Solutions for Our Female Workforce
#
#
# Candidates:
# Germany
# Eyewitness Travel Guide to Germany
# Winner:
# Germany
#
#
# Candidates:
# William Shakespeare - Comedies
# William Shakespeare: Comedies
# William Shakespeare
# Winner:
# William Shakespeare
#
#
# Candidates:
# How to do a Research Project: A Guide for Undergraduate Students
# How to do a research project : a guide for undergraduate students
# How to Do a Research Project
# How to Do a Research Project: A Guide for Undergraduate Students
# Winner:
# How to Do a Research Project
#
#
# Candidates:
# The Business of Tourism Management
# The business of tourism management
# Business of Tourism Management
# Winner:
# The Business of Tourism Management
#
#
# Candidates:
# Communication Skills in Health and Social Care
# Communication skills in health and social care
# Winner:
# Communication Skills in Health and Social Care
#
#
# Candidates:
# Social Theory: A Historical Introduction
# Social theory : a historical introduction
# Social Theory : A Historical Introduction
# Social Theory
# Winner:
# Social Theory
#
#
# Candidates:
# Genius and the Goddess
# The Genius and the Goddess
# Winner:
# The Genius and the Goddess
#
#
# Candidates:
# Critical Thinking: An Exploration of Theory and Practice
# Critical thinking : an exploration of theory and practice
# Winner:
# Critical Thinking: An Exploration of Theory and Practice
#
#
# Candidates:
# Sport, Economy and Society in Britain 1750-1914
# Sport, economy, and society in Britain, 1750-1914
# Winner:
# Sport, Economy and Society in Britain 1750-1914
#
#
# Candidates:
# Destination Branding for Small Cities: The Essentials for Successful Place Branding
# Destination Branding for Small Cities
# Winner:
# Destination Branding for Small Cities
#
#
# Candidates:
# The Child and Family in Context: Developing Ecological Practice in Disadvantaged Communities
# The child and family in context : developing ecological practice in disadvantaged communities
# The Child and Family in Context
# Winner:
# The Child and Family in Context
#
#
# Candidates:
# The U.S. Army War College Guide to National Security Issues
# The U.S. Army War College guide to national security issues
# Winner:
# The U.S. Army War College Guide to National Security Issues
#
#
# Candidates:
# Evangelical Eucharistic Thought in the Church of England
# Evangelical eucharistic thought in the Church of England
# Winner:
# Evangelical Eucharistic Thought in the Church of England
#
#
# Candidates:
# The Euro In Danger
# The Euro in Danger
# Winner:
# The Euro In Danger
#
#
# Candidates:
# Janeway's Immunobiology
# Janeway's immunobiology
# Winner:
# Janeway's Immunobiology
#
#
# Candidates:
# Sociology in Perspective AQA Edition Student Book
# Sociology in perspective
# Sociology in Perspective (Aqa Level)
# Sociology in Perspective: AQA Edition (Aqa Level)
# Winner:
# Sociology in Perspective AQA Edition Student Book
#
#
# Candidates:
# Encyclopedia of Public Health
# The Gale encyclopedia of public health
# Winner:
# Encyclopedia of Public Health
#
#
# Candidates:
# The Unification of Germany: The Anatomy of a Peaceful Revolution
# The unification of Germany or the anatomy of a peaceful revolution
# Winner:
# The Unification of Germany: The Anatomy of a Peaceful Revolution
#
#
# Candidates:
# The Nursing Process: A Global Concept
# The nursing process : a global concept
# Nursing Process A Global Concept
# The Nursing Process
# Winner:
# Nursing Process A Global Concept
#
#
# Candidates:
# International Human Rights Law and Practice
# International human rights law and practice
# Winner:
# International Human Rights Law and Practice
#
#
# Candidates:
# Political Film: The Dialectics of Third Cinema
# Political film : the dialectics of Third cinema
# Winner:
# Political Film: The Dialectics of Third Cinema
#
#
# Candidates:
# The Employee-Organization Relationship: Applications for the 21st Century
# The Employee-Organization Relationship
# The employee-organization relationship
# Winner:
# The Employee-Organization Relationship
#
#
# Candidates:
# Communication in Social Work
# Communication in social work
# Communication and Social Work
# Winner:
# Communication in Social Work
#
#
# Candidates:
# A Practical Guide to Mentoring: Down to Earth Guidance on Making Mentoring Work for You
# A practical guide to mentoring : down to earth guidance on making mentoring work for you
# Winner:
# A Practical Guide to Mentoring: Down to Earth Guidance on Making Mentoring Work for You
#
#
# Candidates:
# Rising Tide: Gender Equality and Cultural Change Around the World
# Rising tide : gender equality and cultural change around the world
# Rising Tide
# Winner:
# Rising Tide
#
#
# Candidates:
# Matematicas Aplicadas a Los Negocios, Las Ciencias Sociales
# Matemáticas aplicadas a los negocios, las ciencia sociales y de la vida
# Winner:
# Matematicas Aplicadas a Los Negocios, Las Ciencias Sociales
#
#
# Candidates:
# Key Methods in Geography
# Key methods in geography
# Winner:
# Key Methods in Geography
#
#
# Candidates:
# Civil Society and Peacebuilding: A Critical Assessment
# Civil society and peacebuilding: a critical assessment
# Winner:
# Civil Society and Peacebuilding: A Critical Assessment
#
#
# Candidates:
# Essentials of Kinesiology for the Physical Therapist Assistant
# Essentials of kinesiology for the physical therapist assistant
# Winner:
# Essentials of Kinesiology for the Physical Therapist Assistant
#
#
# Candidates:
# Obsidian Butterfly
# Obsidian butterfly
# Obsidian Butterfly: An Anita Blake Vampire Hunter Novel
# Winner:
# Obsidian Butterfly
#
#
# Candidates:
# The German Question and Europe: A History
# The German question and Europe : a history
# Winner:
# The German Question and Europe: A History
#
#
# Candidates:
# Advanced Mathematical Concepts: Student Edition
# Merrill advanced mathematical concepts precalculus with applications.
# Advanced Mathematical Concepts
# Winner:
# Advanced Mathematical Concepts
#
#
# Candidates:
# Venice: Lion City
# Venice: Lion City: The Religion of Empire
# Winner:
# Venice: Lion City: The Religion of Empire
#
#
# Candidates:
# The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing
# The life-changing magic of tidying up : the Japanese art of decluttering and organizing
# The Life-Changing Magic of Tidying Up
# Winner:
# The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing
#
#
# Candidates:
# How to Manage Meetings
# How to manage meetings
# How to Manage Meetings (The Sunday Time Creating Success)
# Winner:
# How to Manage Meetings
#
#
# Candidates:
# The Importance of Being Earnest
# The Importance Of Being Earnest
# Winner:
# The Importance of Being Earnest
#
#
# Candidates:
# A Night Out with Robert Burns: The Greatest Poems
# A night out with Robert Burns
# Winner:
# A night out with Robert Burns
#
#
# Candidates:
# Understanding Research for Nursing Students
# Understanding research for nursing students
# Understanding Research for Nursing Students (Transforming Nursing Practice)
# Winner:
# Understanding Research for Nursing Students
#
#
# Candidates:
# The Mindful Way Through Depression: Freeing Yourself from Chronic Unhappiness
# The mindful way through depression : freeing yourself from chronic unhappiness
# The Mindful Way through Depression
# Mindful Way through Depression: Freeing Yourself from Chronic Unhappiness
# Winner:
# The Mindful Way Through Depression: Freeing Yourself from Chronic Unhappiness
#
#
# Candidates:
# Crossing the River
# Crossing the river
# Winner:
# Crossing the River
#
#
# Candidates:
# Cognitive Neuroscience
# Cognitive neuroscience
# Winner:
# Cognitive Neuroscience
#
#
# Candidates:
# Globalizing Women: Transnational Feminist Networks
# Globalizing women transnational feminist networks
# Globalizing women
# Globalizing Women
# Winner:
# Globalizing Women
#
#
# Candidates:
# Valuation for Mergers, Buyouts and Restructuring
# Valuation for mergers, buyouts, and restructuring
# Winner:
# Valuation for Mergers, Buyouts and Restructuring
#
#
# Candidates:
# Handbook of Membrane Separations: Chemical, Pharmaceutical, Food, and Biotechnological Applications
# Handbook of membrane separations : chemical, pharmaceutical, and biotechnological applications
# Handbook of Membrane Separations Chemical Pharmaceutical and Biot
# Handbook of Membrane Separations
# Winner:
# Handbook of Membrane Separations
#
#
# Candidates:
# World of Mathematics
# The World of Mathematics: Volume 3
# Winner:
# The World of Mathematics: Volume 3
#
#
# Candidates:
# Teaching Discipline: A Positive Approach for Educational Development
# Teaching / Discipline : a positive approach for educational development
# Teaching/discipline
# Winner:
# Teaching Discipline: A Positive Approach for Educational Development
#
#
# Candidates:
# SPSS for Social Scientists
# SPSS for social scientists
# Winner:
# SPSS for Social Scientists
#
#
# Candidates:
# Global Marketing Management
# Global marketing management : changes, new challenges, and strategies
# Global marketing management
# Winner:
# Global Marketing Management
#
#
# Candidates:
# Individual Differences in Conscious Experience
# Individual differences in conscious experience
# Winner:
# Individual Differences in Conscious Experience
#
#
# Candidates:
# The Temporal Void
# The temporal void
# Winner:
# The Temporal Void
#
#
# Candidates:
# Walking on Harris and Lewis: 30 Routes in the Outer Hebrides
# Walking on Harris and Lewis : 30 routes in the Outer Hebrides
# Walking on Harris and Lewis
# Winner:
# Walking on Harris and Lewis
#
#
# Candidates:
# International Trade Theory: Capital, Knowledge, Economic Structure, Money, and Prices Over Time
# International trade theory capital, knowledge, economic structure, money, and prices over time
# Winner:
# International Trade Theory: Capital, Knowledge, Economic Structure, Money, and Prices Over Time
#
#
# Candidates:
# The Practice of English Language Teaching
# The practice of English language teaching
# The Practice of English Language Teaching with DVD
# Winner:
# The Practice of English Language Teaching
#
#
# Candidates:
# Business Research Methods
# Business research methods
# Business Research Methods. Alan Bryman, Emma Bell
# Winner:
# Business Research Methods
#
#
# Candidates:
# The People's State: East German Society from Hitler to Honecker
# The people's state East German society from Hitler to Honecker
# The People's State
# Winner:
# The People's State: East German Society from Hitler to Honecker
#
#
# Candidates:
# Ethical Issues in Social Work
# Ethical Issues in Social Work.
# Winner:
# Ethical Issues in Social Work
#
#
# Candidates:
# Ethics in Emergency Medicine
# Ethics in emergency medicine
# Winner:
# Ethics in Emergency Medicine
#
#
# Candidates:
# The business plan workbook
# The Business Plan Workbook: The Definitive Guide to Researching, Writing up and Presenting a Winning Plan
# Winner:
# The Business Plan Workbook: The Definitive Guide to Researching, Writing up and Presenting a Winning Plan
#
#
# Candidates:
# Exploring Key Issues in Education
# Exploring key issues in education
# Winner:
# Exploring Key Issues in Education
#
#
# Candidates:
# Five Germanys I Have Known
# Five Germanys I have known
# Winner:
# Five Germanys I Have Known
#
#
# Candidates:
# Tunnel in the sky
# Tunnel In The Snow
# Winner:
# Tunnel In The Snow
#
#
# Candidates:
# Hollywood Lighting from the Silent Era to Film Noir
# Hollywood lighting from the silent era to film noir
# Winner:
# Hollywood Lighting from the Silent Era to Film Noir
#
#
# Candidates:
# The Voice of the Poet: Adrienne Rich
# Adrienne Rich
# Winner:
# Adrienne Rich
#
#
# Candidates:
# Beyond Quality in Early Childhood Education and Care: Languages of Evaluation
# Beyond Quality In Early Childhood Education And Care.
# Winner:
# Beyond Quality in Early Childhood Education and Care: Languages of Evaluation
#
#
# Candidates:
# The Appeal
# The appeal
# Winner:
# The Appeal
#
#
# Candidates:
# Supporting Identity, Diversity and Language in the Early Years
# Supporting identity, diversity, and language in the early years
# Supporting Identity, Diversity, and Language in the Early Years
# Winner:
# Supporting Identity, Diversity and Language in the Early Years
#
#
# Candidates:
# The Social Entrepreneur: Making Communities Work
# The social entrepreneur : making communities work
# Winner:
# The Social Entrepreneur: Making Communities Work
#
#
# Candidates:
# Integrated Advertising, Promotion and Marketing Communications
# Integrated advertising, promotion, and marketing communications
# Winner:
# Integrated Advertising, Promotion and Marketing Communications
#
#
# Candidates:
# The Cambridge Illustrated History of Archaeology
# The Cambridge illustrated history of archaeology
# Winner:
# The Cambridge Illustrated History of Archaeology
#
#
# Candidates:
# Lifespan Development
# Lifespan development
# Winner:
# Lifespan Development
#
#
# Candidates:
# Connected Marketing: The Viral, Buzz and Word of Mouth Revolution
# Connected marketing
# Winner:
# Connected Marketing: The Viral, Buzz and Word of Mouth Revolution
#
#
# Candidates:
# Bloody Bones
# Bloody bones
# Winner:
# Bloody Bones
#
#
# Candidates:
# Imposing Aid: Emergency Assistance to Refugees
# Imposing aid
# Winner:
# Imposing Aid: Emergency Assistance to Refugees
#
#
# Candidates:
# Fundamentals of Human Neuropsychology
# Fundamentals of human neuropsychology
# Winner:
# Fundamentals of Human Neuropsychology
#
#
# Candidates:
# Introducing Organisational Behaviour and Management
# Introducing organizational behaviour and management
# Introducing Organizational Behaviour and Management
# Winner:
# Introducing Organisational Behaviour and Management
#
#
# Candidates:
# Art from Art
# Andy Warhol, art from art
# Andy Warhol: Art from Art
# Winner:
# Art from Art
#
#
# Candidates:
# Skills for Social Work Practice
# Skills for social work practice
# Winner:
# Skills for Social Work Practice
#
#
# Candidates:
# On Photography
# On photography
# Winner:
# On Photography
#
#
# Candidates:
# Mastering Approaches to Diversity in Social Work
# Mastering approaches to diversity in social work
# Winner:
# Mastering Approaches to Diversity in Social Work
#
#
# Candidates:
# Burnt Offerings
# Burnt offerings
# Winner:
# Burnt Offerings
#
#
# Candidates:
# Sex Differences in Depression
# Sex differences in depression
# Winner:
# Sex Differences in Depression
#
#
# Candidates:
# Collision Course: NATO, Russia, and Kosovo
# Collision course NATO, Russia, and Kosovo
# Winner:
# Collision Course: NATO, Russia, and Kosovo
#
#
# Candidates:
# RE-Thinking Early Childhood, Theory and Practice
# Re thinking early childhood theory and practice
# Winner:
# RE-Thinking Early Childhood, Theory and Practice
#
#
# Candidates:
# An Introduction to Vygotsky
# An introduction to Vygotsky
# Winner:
# An Introduction to Vygotsky
#
#
# Candidates:
# Introduction to Sociology
# Introduction to sociology
# Winner:
# Introduction to Sociology
#
#
# Candidates:
# In Search of Understanding: The Case for Constructivist Classrooms
# In search of understanding : the case for constructivist classrooms
# Winner:
# In Search of Understanding: The Case for Constructivist Classrooms
#
#
# Candidates:
# Mathematics Explained for Primary Teachers
# Mathematics explained for primary teachers.
# Winner:
# Mathematics Explained for Primary Teachers
#
#
# Candidates:
# Pockets of Crime: Broken Windows, Collective Efficacy and the Criminal Point of View
# Pockets of crime : broken windows, collective efficacy, and the criminal point of view
# Pockets of Crime : Broken Windows, Collective Efficacy, and the Criminal Point of View
# Pockets of Crime
# Winner:
# Pockets of Crime
#
#
# Candidates:
# Introduction to Mechatronics and Measurement Systems
# Introduction to mechatronics and measurement systems
# Winner:
# Introduction to Mechatronics and Measurement Systems
#
#
# Candidates:
# Becoming a reflective practitioner
# Becoming a Reflective Practitioner
# Winner:
# Becoming a Reflective Practitioner
#
#
# Candidates:
# Introduction to Sociology
# Introduction to sociology
# Winner:
# Introduction to Sociology
#
#
# Candidates:
# The Developing Child
# The developing child
# Winner:
# The Developing Child
#
#
# Candidates:
# BMA Concise Guide to Medicine and Drugs
# BMA concise guide to medicine and drugs.
# Winner:
# BMA Concise Guide to Medicine and Drugs
#
#
# Candidates:
# Britain Since 1707
# Britain since 1707
# Winner:
# Britain Since 1707
#
#
# Candidates:
# The laughing corpse
# The Laughing Corpse (Anita Blake Vampire Hunter Series #2)
# The Laughing Corpse
# Winner:
# The Laughing Corpse
#
#
# Candidates:
# Business Research Projects
# Business research projects
# Winner:
# Business Research Projects
#
#
# Candidates:
# The Routledge Physical Education Reader
# The routledge physical education reader
# Winner:
# The Routledge Physical Education Reader
#
#
# Candidates:
# Successful Legal Writing
# Successful legal writing
# Winner:
# Successful Legal Writing
#
#
# Candidates:
# Project Management in Construction
# Project management in construction
# Winner:
# Project Management in Construction
#
#
# Candidates:
# An Innovative Approach Language Teaching
# Innovative approaches to language teaching
# Innovative Approaches to Language Teaching
# Winner:
# An Innovative Approach Language Teaching
#
#
# Candidates:
# Tourism: Principles and Practice
# Tourism : principles and practice
# Tourism
# Winner:
# Tourism
#
#
# Candidates:
# Billy Budd and Other Stories
# Billy Budd
# Winner:
# Billy Budd and Other Stories
#
#
# Candidates:
# The Material Image: Art and the Real in Film
# The material image
# Winner:
# The Material Image: Art and the Real in Film
#
#
# Candidates:
# Sociology, Work and Organisation
# Sociology, work and organisation
# Winner:
# Sociology, Work and Organisation
#
#
# Candidates:
# Henry James Against the Aesthetic Movement: Essays on the Middle and Late Fiction
# Henry James Against the Aesthetic Movement
# Winner:
# Henry James Against the Aesthetic Movement
#
#
# Candidates:
# Feminism Crit Concepts V3
# Feminism : critical concepts in literary and cultural studies
# Feminism
# Winner:
# Feminism
